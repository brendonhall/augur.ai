# %%
YSD_DICT = {'DH Data Invalid': 0,
            'Manual Stop': 0,
            'PwrFail Sys Stop': 0,
            'Ext Flt Warning': 0,
            'No Faults/Warnin': 0,
            'Overload Fault': 0,
            'OVER CURRENT': 0,
            'No Faults or War': 0,
            'Underload Fault': 0,
            'DHwinding THi Fl': 0,
            'INPUT LINE SUPER': 0,
            'Motor Temp Hi': 0,'V7 Fault PL': 0,
            'V7 Dig In 2': 0,
            'Watchdog Reset': 0,
            'V7 Fault OL2':0,
            'Motor Overload F': 0,
            'Auxiliary Input': 0,
            'Heatsink Overtem': 0,
            'Hardware OverCur': 0,
            'V7 Fault UV': 0,
            'Auto Restart Tri': 0,
            'Hardware 3 FAULT': 0,
            'V7 Dig In 3': 0,
            'Start Failed': 0,
            'Underload': 0,
            'V7 Dig In 1': 0,
            'V7 Fault OV': 0,
            'DInput 1 Lckout': 0,
            'DInput 1 Fault': 0,
            'IGBT TEMPERATURE': 0,
            'Dig In 12': 0,
            'Underload FAULT': 0,
            'RTD 5 OH': 0,
            'Drive Freq Low': 0,
            'VFD EXT FAULT': 0,
            'VFD BUS ComFLT': 0,
            'Digital Input 1': 0,
            'BUS COMM FAULT': 0,
            'DEFAULT': 0,
            'KEYPAD_STOP': 0,
            'Intake Temp Hi': 0,
            'V7 Dig In 4': 0,
            'Underload Flt': 0,
            'Underload Lckout': 0,
            'OVER_CURRENT_A': 0,
            'Phase A pos IOT': 0,
            'UNDERLOAD_SD': 0,
            'IO1DI1_SD': 0,
            'OVERLOAD_LCK': 0,
            '1837': 0,
            '1838': 0,
            'UAB1_THLD_SD': 0,
            'MOTOR_FAILED_TO_': 0,
            'GasLckMaxCycLcko': 0,
            'VFD OVER CURRENT': 0,
            'PID HiLv Stop': 0,
            '0': 0,
            'Phase B pos IOT': 0,
            'DHwinding THi Lc': 0,
            'Lo Freq Fault': 0,
            'Lo Freq Lockout': 0,
            'V7 HBB E-STOP': 0,
            'DInput 2 Fault': 0,
            'Self-Stop': 0,
            'Drive Disabled': 0,
            'POWER FAILURE': 0,
            'POWER UP': 0,
            'Aux Input 8': 0,
            'Decel Inhibit FA': 0,
            'NA 082': 0,
            'TEMP 2 FAULT': 0,
            'MOTOR UNDRLOAD': 0,
            'UAB2_THLD_SD': 0,
            'DHintake P Lo Lc': 0,
            'Breaker 2 Fault': 0,
            'Intake Press Low': 0,
            'Input Cur.Unbal': 0,
            'Dig In 4': 0,
            'Input VoltUnbal': 0,
            'Input UnderVolt': 0,
            'NA 160': 0,
            '4294967295': 0,
            'A Fault': 0,
            'IGBT TEMP': 0,
            'AFE_A Start Flt': 0,
            'OverVoltage FAUL': 0,
            'Undervoltage FAU': 0,
            'NA 083': 0,
            'Drive Overload F': 0,
            'NA 16': 0,
            'Ground FAULT': 0,
            'GDI COMM_FAILURE': 0,
            'converter watchd': 0,
            '1598': 0,
            '252': 0,
            'CSU_COMFAIL_SD': 0,
            'VFD SLOT FLT': 0,
            'Parameters Defau': 0,
            'OVERVOLT_SD': 0,
            '1769': 0,
            'Phase C pos IOT': 0,
            'Phase B neg IOT': 0,
            'OVER_CURRENT_B': 0,
            'Parameter Checks': 0,
            'I UNBAL LCK': 0,
            '1849': 0,
            'Phase A neg IOT': 0,
            'UNDERVOLT_SD': 0,
            'SYSTEM FAULT': 0,
            'OVER_CURRENT_C'
            'V UNBAL_SD': 0,
            'DCBus V Hi Locko': 0,
            'DCBus V Hi Fault': 0,
            'AFE_B Start Lcko'
            'UNKNOWN FAULT': 0,
            'I UNBAL SD': 0,
            'Filter Overheat': 0,
            'V7 Fault LF': 0,
            'V7 Fault OC': 0,
            'SCADA_STOP': 0,}
similar = [
 'IGBT TEMP',
 'IGBT TEMPERATURE',
 'Underload FAULT',
 'Underload Fault',
 'Underload Flt',
]
len(YSD_DICT.keys())
sorted(YSD_DICT.keys())
# Out:
# ['0',
#  '1598',
#  '1769',
#  '1837',
#  '1838',
#  '1849',
#  '252',
#  '4294967295',
#  'A Fault',
#  'AFE_A Start Flt',
#  'AFE_B Start LckoUNKNOWN FAULT',
#  'Auto Restart Tri',
#  'Aux Input 8',
#  'Auxiliary Input',
#  'BUS COMM FAULT',
#  'Breaker 2 Fault',
#  'CSU_COMFAIL_SD',
#  'DCBus V Hi Fault',
#  'DCBus V Hi Locko',
#  'DEFAULT',
#  'DH Data Invalid',
#  'DHintake P Lo Lc',
#  'DHwinding THi Fl',
#  'DHwinding THi Lc',
#  'DInput 1 Fault',
#  'DInput 1 Lckout',
#  'DInput 2 Fault',
#  'Decel Inhibit FA',
#  'Dig In 12',
#  'Dig In 4',
#  'Digital Input 1',
#  'Drive Disabled',
#  'Drive Freq Low',
#  'Drive Overload F',
#  'Ext Flt Warning',
#  'Filter Overheat',
#  'GDI COMM_FAILURE',
#  'GasLckMaxCycLcko',
#  'Ground FAULT',
#  'Hardware 3 FAULT',
#  'Hardware OverCur',
#  'Heatsink Overtem',
#  'I UNBAL LCK',
#  'I UNBAL SD',
#  'IGBT TEMP',
#  'IGBT TEMPERATURE',
#  'INPUT LINE SUPER',
#  'IO1DI1_SD',
#  'Input Cur.Unbal',
#  'Input UnderVolt',
# ...
