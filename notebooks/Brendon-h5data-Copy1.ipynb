# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import h5py

# %%
df = pd.read_hdf('/home/ubuntu/data/wells/12_361.h5', 'data')

# %%
df = pd.read_hdf('/home/ubuntu/data/wells/12_361.h5', 'data')

# %%
df.plot
# Out:
#                              EDH  YRUN        IDH        VDH         PINP  \
# time
# 2017-07-09 23:30:00  2007.000000   0.0  33.274556  10.110000  1653.500000
# 2017-07-09 23:31:00  2007.000000   0.0  33.274046  10.109351  1653.454580
# 2017-07-09 23:32:00  2007.000000   0.0  33.182443  10.107061  1653.294275
# 2017-07-09 23:33:00  2007.000000   0.0  33.090840  10.104771  1653.133969
# 2017-07-09 23:34:00  2007.000000   0.0  32.999237  10.102481  1652.973664
# 2017-07-09 23:35:00  2007.000000   0.0  32.907634  10.100191  1652.813359
# 2017-07-09 23:36:00  2007.183333   0.0  33.101667  10.027583  1652.946667
# 2017-07-09 23:37:00  2007.383333   0.0  33.321667   9.948583  1653.106667
# 2017-07-09 23:38:00  2007.583333   0.0  33.541667   9.869583  1653.266667
# 2017-07-09 23:39:00  2007.783333   0.0  33.761667   9.790583  1653.426667
# 2017-07-09 23:40:00  2007.983333   0.0  33.981667   9.711583  1653.586667
# 2017-07-09 23:41:00  2007.816667   0.0  33.945000   9.632583  1652.390000
# ...

# %%
df['PINP'].plot(figsize=(18,5))

# %%
# Out:
# (52011, 6)
